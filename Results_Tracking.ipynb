# %% [markdown]
# ## Results of Tracking

# %% [markdown]
# This notebook is designed to show results of tracking system, which the videos are from the benchmark Tracking dataset.

# %%
import io
import base64
from IPython.display import HTML


video_name = 'Deer'
mp4_video_file_name = './out_videos/' + video_name + '_video.mp4' 

video = io.open(mp4_video_file_name, 'r+b').read()
encoded = base64.b64encode(video)
video_tag = '<video controls alt="test" src="data:video/x-m4v;base64,{0}">'.format(encoded)
HTML(data=video_tag)
# Out:
# <video controls alt="test" src="data:video/x-m4v;base64,...">
