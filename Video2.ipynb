# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random

# %matplotlib inline

# %%
img = cv2.imread("cameraman.png", cv2.CV_LOAD_IMAGE_GRAYSCALE)

# %%
num_frames = 60

# %%
video_filename = "camera_video.avi"
video = cv2.VideoWriter()
video.open(video_filename, cv2.cv.CV_FOURCC('F','M', 'P','4'), 15, img.shape, 0)
if video.isOpened():
    video.write(img)
    oldH = np.eye(3)
    for tt in range(1, num_frames):
        w = 0.05*(2*random.random() - 1)
        tx = 5*(2*random.random() - 1)
        ty = 5*(2*random.random() - 1)
        current_H = np.array([[1, -w, tx], [w, 1, ty], [0, 0, 1]])
        H = np.dot(current_H, oldH)
        oldH = H.copy()
        timg = cv2.warpAffine(img, H[0:2,:],None)
        video.write(timg)
    video.release()
else:
      print "Cannot open", video_filename, "for writing."

# %%
# Converts AVI into MP4 for loading into notebook
# ffmpeg 
import subprocess
import shlex
cmd = "ffmpeg -y -i " + video_filename + " -c:v libx264 " + mp4_video_file_name 
retcode = subprocess.call(shlex.split(cmd))
print cmd
if retcode == 0:
    print "done."
else:
    print >>subprocess.stderr
# Out:
# ffmpeg -y -i camera_video.avi -c:v libx264 camera_video.avi.mp4
# done.

# %%
import io
import base64
from IPython.display import HTML

video = io.open(mp4_video_file_name, 'r+b').read()
encoded = base64.b64encode(video)
video_tag = '<video controls alt="test" src="data:video/x-m4v;base64,{0}">'.format(encoded)
HTML(data=video_tag)
# Out:
# <video controls alt="test" src="data:video/x-m4v;base64,...">

# %%
oldH = np.eye(3)
